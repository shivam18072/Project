# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
laliga = pd.read_csv('C:/Users/ap983/Desktop/P. SERVER/3.GREAT LEARNING/PENDING/STATISTICS//Laliga 1.csv')
laliga
# Out:
#     Pos              Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1       Real Madrid       86   4385        2762     1647        552
# 1     2         Barcelona       86   4262        2762     1581        573
# 2     3   Atletico Madrid       80   3442        2614     1241        598
# 3     4          Valencia       82   3386        2664     1187        616
# 4     5   Athletic Bilbao       86   3368        2762     1209        633
# ..  ...               ...      ...    ...         ...      ...        ...
# 56   57             Xerez        1     34          38        8         10
# 57   58            Condal        1     22          30        7          8
# 58   59   Atletico Tetuan        1     19          30        7          5
# 59   60  Cultural Leonesa        1     14          30        5          4
# 60   61            Girona        1      -           -        -          -
#
#    GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# ...

# %%
laliga.head()
# Out:
#    Pos             Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0    1      Real Madrid       86   4385        2762     1647        552
# 1    2        Barcelona       86   4262        2762     1581        573
# 2    3  Atletico Madrid       80   3442        2614     1241        598
# 3    4         Valencia       82   3386        2664     1187        616
# 4    5  Athletic Bilbao       86   3368        2762     1209        633
#
#   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 0       563     5947         3140       33        23     8      8     3     4
# 1       608     5900         3114       25        25    12     12     4     6
# 2       775     4534         3309       10         8    16      9     7     6
# 3       861     4398         3469        6         6    10     11    10     7
# 4       920     4631         3700        8         7    10      5     8    10
#
#     T    Debut Since/LastApp  BestPosition
# ...

# %%
laliga.head()
# Out:
#    Pos             Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0    1      Real Madrid       86   4385        2762     1647        552
# 1    2        Barcelona       86   4262        2762     1581        573
# 2    3  Atletico Madrid       80   3442        2614     1241        598
# 3    4         Valencia       82   3386        2664     1187        616
# 4    5  Athletic Bilbao       86   3368        2762     1209        633
#
#   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 0       563     5947         3140       33        23     8      8     3     4
# 1       608     5900         3114       25        25    12     12     4     6
# 2       775     4534         3309       10         8    16      9     7     6
# 3       861     4398         3469        6         6    10     11    10     7
# 4       920     4631         3700        8         7    10      5     8    10
#
#     T    Debut Since/LastApp  BestPosition
# ...

# %%
laliga.rename(columns={'team':'Pos'},inplace=False)
# Out:
#     Pos              Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1       Real Madrid       86   4385        2762     1647        552
# 1     2         Barcelona       86   4262        2762     1581        573
# 2     3   Atletico Madrid       80   3442        2614     1241        598
# 3     4          Valencia       82   3386        2664     1187        616
# 4     5   Athletic Bilbao       86   3368        2762     1209        633
# ..  ...               ...      ...    ...         ...      ...        ...
# 56   57             Xerez        1     34          38        8         10
# 57   58            Condal        1     22          30        7          8
# 58   59   Atletico Tetuan        1     19          30        7          5
# 59   60  Cultural Leonesa        1     14          30        5          4
# 60   61            Girona        1      -           -        -          -
#
#    GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# ...

# %%
laliga.tail()
# Out:
#     Pos              Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 56   57             Xerez        1     34          38        8         10
# 57   58            Condal        1     22          30        7          8
# 58   59   Atletico Tetuan        1     19          30        7          5
# 59   60  Cultural Leonesa        1     14          30        5          4
# 60   61            Girona        1      -           -        -          -
#
#    GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# 56        20       38           66        -         -     -      -     -
# 57        15       37           57        -         -     -      -     -
# 58        18       51           85        -         -     -      -     -
# 59        21       34           65        -         -     -      -     -
# 60         -        -            -        -         -     -      -     -
#
#    Sixth  T    Debut Since/LastApp  BestPosition
# ...

# %%
laliga.shape
# Out:
# (61, 20)

# %%
laliga.columns
# Out:
# Index(['Pos', 'Team', 'Seasons', 'Points', 'GamesPlayed', 'GamesWon',
#        'GamesDrawn', 'GamesLost', 'GoalsFor', 'GoalsAgainst', 'Champion',
#        'Runner-up', 'Third', 'Fourth', 'Fifth', 'Sixth', 'T', 'Debut',
#        'Since/LastApp', 'BestPosition'],
#       dtype='object')

# %%
laliga.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pos            61 non-null     int64
#  1   Team           61 non-null     object
#  2   Seasons        61 non-null     int64
#  3   Points         61 non-null     object
#  4   GamesPlayed    61 non-null     object
#  5   GamesWon       61 non-null     object
#  6   GamesDrawn     61 non-null     object
#  7   GamesLost      61 non-null     object
#  8   GoalsFor       61 non-null     object
#  9   GoalsAgainst   61 non-null     object
#  10  Champion       61 non-null     object
#  11  Runner-up      61 non-null     object
#  12  Third          61 non-null     object
#  13  Fourth         61 non-null     object
#  14  Fifth          61 non-null     object
#  15  Sixth          61 non-null     object
#  16  T              61 non-null     object
# ...

# %%
laliga.describe()
# Out:
#              Pos    Seasons  BestPosition
# count  61.000000  61.000000     61.000000
# mean   31.000000  24.000000      7.081967
# std    17.752934  26.827225      5.276663
# min     1.000000   1.000000      1.000000
# 25%    16.000000   4.000000      3.000000
# 50%    31.000000  12.000000      6.000000
# 75%    46.000000  38.000000     10.000000
# max    61.000000  86.000000     20.000000

# %%
laliga.isnull().sum()
# Out:
# Pos              0
# Team             0
# Seasons          0
# Points           0
# GamesPlayed      0
# GamesWon         0
# GamesDrawn       0
# GamesLost        0
# GoalsFor         0
# GoalsAgainst     0
# Champion         0
# Runner-up        0
# Third            0
# Fourth           0
# Fifth            0
# Sixth            0
# T                0
# Debut            0
# Since/LastApp    0
# BestPosition     0
# dtype: int64

# %% [markdown]
# -  Reading the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data

# %%
laliga.replace('-',np.nan,inplace = True)
laliga =laliga.fillna(0)
laliga
# Out:
#     Pos              Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1       Real Madrid       86   4385        2762     1647        552
# 1     2         Barcelona       86   4262        2762     1581        573
# 2     3   Atletico Madrid       80   3442        2614     1241        598
# 3     4          Valencia       82   3386        2664     1187        616
# 4     5   Athletic Bilbao       86   3368        2762     1209        633
# ..  ...               ...      ...    ...         ...      ...        ...
# 56   57             Xerez        1     34          38        8         10
# 57   58            Condal        1     22          30        7          8
# 58   59   Atletico Tetuan        1     19          30        7          5
# 59   60  Cultural Leonesa        1     14          30        5          4
# 60   61            Girona        1      0           0        0          0
#
#    GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# ...

# %% [markdown]
# - Print all the teams which have started playing between 1930-1980. (5 points)

# %%
laliga.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pos            61 non-null     int64
#  1   Team           61 non-null     object
#  2   Seasons        61 non-null     int64
#  3   Points         61 non-null     object
#  4   GamesPlayed    61 non-null     object
#  5   GamesWon       61 non-null     object
#  6   GamesDrawn     61 non-null     object
#  7   GamesLost      61 non-null     object
#  8   GoalsFor       61 non-null     object
#  9   GoalsAgainst   61 non-null     object
#  10  Champion       61 non-null     object
#  11  Runner-up      61 non-null     object
#  12  Third          61 non-null     object
#  13  Fourth         61 non-null     object
#  14  Fifth          61 non-null     object
#  15  Sixth          61 non-null     object
#  16  T              61 non-null     object
# ...

# %%
laliga['Debut'] = laliga['Debut'].astype(str).str[:4].astype(int)
laliga_new = laliga[laliga['Debut'].between(1930,1980)]
laliga_new
# Out:
#     Pos                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 3     4             Valencia       82   3386        2664     1187        616
# 5     6              Sevilla       73   2819        2408      990        531
# 8     9             Zaragoza       58   2109        1986      698        522
# 9    10           Real Betis       51   1884        1728      606        440
# 10   11  Deportivo La Coruna       45   1814        1530      563        392
# 11   12           Celta Vigo       51   1789        1698      586        389
# 12   13           Valladolid       42   1471        1466      463        384
# 14   15       Sporting Gijon       43   1389        1458      471        358
# 15   16              Osasuna       37   1351        1318      426        327
# 16   17               Malaga       36   1314        1255      390        330
# 17   18               Oviedo       38   1174        1192      408        292
# ...

# %% [markdown]
# - Print the list of teams which came Top 5 in terms of points (2.5 points)

# %%
laliga['Points'] = laliga.Points.astype(float)
laliga.sort_values(by=['Points'],ascending = False)
# Out:
#     Pos              Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 0     1       Real Madrid       86  4385.0        2762     1647        552
# 1     2         Barcelona       86  4262.0        2762     1581        573
# 2     3   Atletico Madrid       80  3442.0        2614     1241        598
# 3     4          Valencia       82  3386.0        2664     1187        616
# 4     5   Athletic Bilbao       86  3368.0        2762     1209        633
# ..  ...               ...      ...     ...         ...      ...        ...
# 56   57             Xerez        1    34.0          38        8         10
# 57   58            Condal        1    22.0          30        7          8
# 58   59   Atletico Tetuan        1    19.0          30        7          5
# 59   60  Cultural Leonesa        1    14.0          30        5          4
# 60   61            Girona        1     0.0           0        0          0
#
# ...

# %% [markdown]
# - Write a function with name “Goal_diff_count” which should return all the teams with their
# Goal Differences. Using the same function, find the team which has maximum and
# minimum goal difference. (5 points

# %%
laliga.head(1)
# Out:
#    Pos         Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 0    1  Real Madrid       86  4385.0        2762     1647        552
#
#   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 0       563     5947         3140       33        23     8      8     3     4
#
#     T  Debut Since/LastApp  BestPosition
# 0  79   1929          1929             1

# %%
laliga.tail(1)
# Out:
#     Pos    Team  Seasons  Points GamesPlayed GamesWon GamesDrawn GamesLost  \
# 60   61  Girona        1     0.0           0        0          0         0
#
#    GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  T  \
# 60        0            0        0         0     0      0     0     0  0
#
#     Debut Since/LastApp  BestPosition
# 60   2017       2017-18             9

# %% [markdown]
# - Create a new column with name “Winning Percent” and append it to the data set (5 points)
# Percentage of Winning = (GamesWon / GamesPlayed)*100
# If there are any numerical error, replace it with 0%
# Print the top 5 teams which has the highest Winning percentage

# %%
laliga['GamesWon'] = laliga.GamesWon.astype(float)
laliga['GamesPlayed'] = laliga.GamesPlayed.astype(float)
laliga['WinningPercent'] = (laliga.iloc[:,5]/laliga.iloc[:,4])*100
laliga
# Out:
#     Pos              Team  Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 0     1       Real Madrid       86  4385.0       2762.0    1647.0        552
# 1     2         Barcelona       86  4262.0       2762.0    1581.0        573
# 2     3   Atletico Madrid       80  3442.0       2614.0    1241.0        598
# 3     4          Valencia       82  3386.0       2664.0    1187.0        616
# 4     5   Athletic Bilbao       86  3368.0       2762.0    1209.0        633
# ..  ...               ...      ...     ...          ...       ...        ...
# 56   57             Xerez        1    34.0         38.0       8.0         10
# 57   58            Condal        1    22.0         30.0       7.0          8
# 58   59   Atletico Tetuan        1    19.0         30.0       7.0          5
# 59   60  Cultural Leonesa        1    14.0         30.0       5.0          4
# 60   61            Girona        1     0.0          0.0       0.0          0
#
# ...

# %% [markdown]
#  - 6. Group teams based on their “Best position” and print the sum of their points for all positions
# (10 points)
# Eg: Best Position Points
# - 1 25000
# - 2 7000

# %%
laliga.groupby([laliga.iloc[:,10]]).sum()
# Out:
#            Pos  Seasons   Points  GamesPlayed  GamesWon   Debut  BestPosition  \
# Champion
# 0         1841      805  27054.0      27074.0    8654.0  102111           423
# 1           27      169   6517.0       5666.0    2159.0    5807             3
# 10           3       80   3442.0       2614.0    1241.0    1929             1
# 2            8       70   2573.0       2302.0     864.0    1929             1
# 25           2       86   4262.0       2762.0    1581.0    1929             1
# 33           1       86   4385.0       2762.0    1647.0    1929             1
# 6            4       82   3386.0       2664.0    1187.0    1931             1
# 8            5       86   3368.0       2762.0    1209.0    1929             1
#
#           WinningPercent
# Champion
# 0            1478.698381
# 1             112.979787
# 10             47.475134
# 2              37.532580
# 25             57.241130
# 33             59.630702
# 6              44.557057
# 8              43.772629

# %%
laliga.head(2)
# Out:
#    Pos         Team  Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 0    1  Real Madrid       86  4385.0       2762.0    1647.0        552
# 1    2    Barcelona       86  4262.0       2762.0    1581.0        573
#
#   GamesLost GoalsFor GoalsAgainst  ... Runner-up Third Fourth Fifth Sixth   T  \
# 0       563     5947         3140  ...        23     8      8     3     4  79
# 1       608     5900         3114  ...        25    12     12     4     6  83
#
#   Debut  Since/LastApp BestPosition  WinningPercent
# 0  1929           1929            1       59.630702
# 1  1929           1929            1       57.241130
#
# [2 rows x 21 columns]
